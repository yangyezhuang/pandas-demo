# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


data1 = pd.read_csv('../data/food_risk_o.csv')
data1.head(3)
# Out:
#                                    店铺ID             店铺名        开始时间       风险值  \
# 0  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-01-01  0.147242
# 1  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-02-01  0.187812
# 2  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-03-01  0.313739
#
#    地区名    销售额
# 0  滨湖区  313.5
# 1  滨湖区  376.2
# 2  滨湖区  501.6

# %%
data1.shape
# Out:
# (70943, 6)

# %%
data2 = pd.read_csv('../data/food_record.csv')
data2.head(3)
# Out:
#                                    店铺ID             店铺名        开始时间       风险值
# 0  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-01-01  0.147242
# 1  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-02-01  0.187812
# 2  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-03-01  0.313739

# %%
data2.shape
# Out:
# (72502, 4)

# %%
df = pd.merge(data1,data2,how='right',on=['店铺ID','开始时间'])
df.head(3)
# Out:
#                                    店铺ID           店铺名_x        开始时间     风险值_x  \
# 0  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-01-01  0.147242
# 1  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-02-01  0.187812
# 2  3d8ab846-7725-11ea-98c9-525400c74cae  1+7水饺店(金科世界城店)  2019-03-01  0.313739
#
#    地区名    销售额           店铺名_y     风险值_y
# 0  滨湖区  313.5  1+7水饺店(金科世界城店)  0.147242
# 1  滨湖区  376.2  1+7水饺店(金科世界城店)  0.187812
# 2  滨湖区  501.6  1+7水饺店(金科世界城店)  0.313739

# %%
df.shape
# Out:
# (72502, 8)

# %%
# 删除多余列
df = df.drop(['店铺名_y','风险值_y'],axis=1)
df
# Out:
#                                        店铺ID            店铺名_x        开始时间  \
# 0      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-01-01
# 1      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-02-01
# 2      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-03-01
# 3      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-04-01
# 4      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-05-01
# ...                                     ...              ...         ...
# 72497  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-08-01
# 72498  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-09-01
# 72499  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-10-01
# 72500  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-11-01
# 72501  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-12-01
#
#           风险值_x  地区名     销售额
# 0      0.147242  滨湖区   313.5
# 1      0.187812  滨湖区   376.2
# ...

# %%
#  查看重复值情况
df.duplicated().sum()
# Out:
# 0

# %%
# 查看缺失值情况
df.isnull().sum()
# Out:
# 店铺ID        0
# 店铺名_x    1559
# 开始时间        0
# 风险值_x    1559
# 地区名      1559
# 销售额      1559
# dtype: int64

# %%
# 删除空值行
df.dropna()
# Out:
#                                        店铺ID            店铺名_x        开始时间  \
# 0      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-01-01
# 1      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-02-01
# 2      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-03-01
# 3      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-04-01
# 4      3d8ab846-7725-11ea-98c9-525400c74cae   1+7水饺店(金科世界城店)  2019-05-01
# ...                                     ...              ...         ...
# 72497  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-08-01
# 72498  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-09-01
# 72499  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-10-01
# 72500  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-11-01
# 72501  dcedfb83-7727-11ea-98c9-525400c74cae  龙门铁板炒饭（崇安寺步行街店）  2019-12-01
#
#           风险值_x  地区名     销售额
# 0      0.147242  滨湖区   313.5
# 1      0.187812  滨湖区   376.2
# ...
